# %%
pip install bing-image-downloader

# %%
pip install opencv-python

# %%
pip install matplotlib

# %%
pip install scikit-image

# %%
pip install -U scikit-learn

# %%
pip install pandas

# %%
from bing_image_downloader import downloader
downloader.download("pizza",limit =20,output_dir ='images')

# %%
from bing_image_downloader import downloader
downloader.download("pasta",limit =20,output_dir ='images')

# %%
path =r'images\pizza\Image_1.jpg'
import cv2
import matplotlib.pyplot as plt

i =cv2.imread(path)
i =cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)
plt.show()

# %%
import os

path =r'C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza'
print(path)
for filename in os.listdir(path):
    i =cv2.imread(os.path.join(path,filename))
    i =cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
    print(i.shape)
# Out:
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# (1267, 1900, 3)
# (1133, 1700, 3)
# (611, 1024, 3)
# (850, 1300, 3)
# (6650, 5000, 3)
# (600, 600, 3)
# (933, 1311, 3)
# (1760, 2640, 3)
# (798, 1200, 3)
# (1267, 1900, 3)
# (680, 1024, 3)
# (1464, 2455, 3)
# (1464, 2455, 3)
# (680, 1024, 3)
# (705, 1070, 3)
# (500, 900, 3)
# (2848, 4302, 3)
# (2171, 1500, 3)
# (1536, 1536, 3)
# (960, 1280, 3)

# %%
from skimage.io import imread
from skimage.transform import resize
import numpy as np

# %%
target =[]  #list of target(output)
flat_data=[] #image in flatten style
images = []

path =r'C:\Users\Midhun\Desktop\DM-Mini-Project\images'

for dirpath,dirnames,filenames in os.walk(path):
    for filename in filenames:
        
        head, tail = os.path.split(dirpath)

        print("training ", tail)
        # print(head)

        category = dirpath.split('/')[-1]
        
        print(category)
        
        target.append(tail)
        img =imread(f'{category}/{filename}')
        img_resize = resize(img,(50,50,3))
        flat_data.append(img_resize.flatten())
        images.append(img_resize)
    
        
flat_data = np.array(flat_data)
target = np.array(target)
images = np.array(images)

print(flat_data.shape)
print(target)
# Out:
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pasta
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pasta
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# training  pizza
# C:\Users\Midhun\Desktop\DM-Mini-Project\images\pizza
# (40, 7500)
# ['pasta' 'pasta' 'pasta' 'pasta' 'pasta' 'pasta' 'pasta' 'pasta' 'pasta'
#  'pasta' 'pasta' 'pasta' 'pasta' 'pasta' 'pasta' 'pasta' 'pasta' 'pasta'
#  'pasta' 'pasta' 'pizza' 'pizza' 'pizza' 'pizza' 'pizza' 'pizza' 'pizza'
#  'pizza' 'pizza' 'pizza' 'pizza' 'pizza' 'pizza' 'pizza' 'pizza' 'pizza'
#  'pizza' 'pizza' 'pizza' 'pizza']

# %%
print(img_resize)
print("#" )
print(flat_data)
# Out:
# [[[0.15294118 0.18823529 0.22352941]
#   [0.15686275 0.19607843 0.23921569]
#   [0.16470588 0.21176471 0.26666667]
#   ...
#   [0.59411765 0.41745098 0.30941176]
#   [0.66313725 0.47058824 0.31686275]
#   [0.61752941 0.3887451  0.22392157]]
#
#  [[0.14901961 0.18431373 0.21960784]
#   [0.15647059 0.19215686 0.23137255]
#   [0.16470588 0.21176471 0.26470588]
#   ...
#   [0.65921569 0.47215686 0.33098039]
#   [0.69007843 0.51490196 0.35647059]
#   [0.63019608 0.50196078 0.37372549]]
#
#  [[0.15686275 0.18823529 0.22352941]
#   [0.15862745 0.19607843 0.23509804]
#   [0.16862745 0.21176471 0.26666667]
#   ...
#   [0.66862745 0.57352941 0.46470588]
#   [0.51098039 0.44431373 0.35254902]
#   [0.31156863 0.28607843 0.24039216]]
#
#  ...
#
#  [[0.62666667 0.29215686 0.13137255]
#   [0.65470588 0.33686275 0.15098039]
#   [0.77058824 0.5254902  0.29705882]
#   ...
#   [0.14019608 0.19215686 0.2745098 ]
#   [0.1254902  0.18039216 0.26058824]
#   [0.12156863 0.17313725 0.24960784]]
#
#  [[0.68745098 0.40392157 0.21486275]
#   [0.76078431 0.49933333 0.26823529]
#   [0.82352941 0.64980392 0.45176471]
#   ...
#   [0.1254902  0.18823529 0.27058824]
#   [0.1254902  0.18039216 0.2627451 ]
#   [0.11764706 0.17647059 0.25133333]]
#
#  [[0.68352941 0.45960784 0.27137255]
#   [0.7725098  0.58       0.37568627]
#   [0.81960784 0.68039216 0.52156863]
#   ...
#   [0.1254902  0.18039216 0.25882353]
#   [0.11764706 0.17254902 0.24670588]
#   [0.11372549 0.16862745 0.23921569]]]
# #
# [[0.79396078 0.79607843 0.79215686 ... 0.90196078 0.90588235 0.92156863]
#  [0.98039216 0.98039216 0.99346405 ... 0.91372549 0.91372549 0.98235294]
#  [0.64640523 0.64901961 0.93921569 ... 0.05882353 0.0627451  0.84117647]
#  ...
#  [0.6627451  0.65882353 0.63921569 ... 0.82745098 0.80784314 0.79215686]
#  [0.88235294 0.8828251  0.88674667 ... 0.79168471 0.59560627 0.23090039]
#  [0.15294118 0.18823529 0.22352941 ... 0.11372549 0.16862745 0.23921569]]

# %%
import pandas as pd

df =pd.DataFrame(flat_data)

df['Target']=target

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.793961  0.796078  0.792157  0.815686  0.792157  0.705882  0.848863
# 1  0.980392  0.980392  0.993464  0.980392  0.980392  0.993464  0.980392
# 2  0.646405  0.649020  0.939216  0.641830  0.643137  0.938562  0.641444
# 3  0.818627  0.872549  0.956863  0.784314  0.833333  0.921569  0.694118
# 4  0.905882  0.907843  0.981699  0.905882  0.907843  0.981699  0.901961
#
#           7         8         9  ...      7491      7492      7493      7494  \
# 0  0.827451  0.752784  0.874510  ...  0.909804  0.913725  0.921882  0.905882
# 1  0.980392  0.993464  0.980392  ...  0.921516  0.921255  0.983608  0.917647
# 2  0.641000  0.937908  0.606514  ...  0.050980  0.052941  0.839216  0.062745
# 3  0.743137  0.833333  0.552941  ...  0.701961  0.713725  0.803922  0.786275
# 4  0.903922  0.981046  0.894118  ...  0.598941  0.587569  0.929203  0.671713
#
#        7495      7496      7497      7498      7499  Target
# 0  0.909804  0.921569  0.901961  0.905882  0.921569   pasta
# 1  0.917647  0.983007  0.913725  0.913725  0.982353   pasta
# 2  0.064706  0.841176  0.058824  0.062745  0.841176   pasta
# 3  0.794118  0.868627  0.768627  0.780392  0.856863   pasta
# 4  0.663534  0.941222  0.723734  0.719574  0.950217   pasta
#
# [5 rows x 7501 columns]

# %%
x=flat_data
y=df.Target

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (30, 7500)
# (10, 7500)
# (30,)
# (10,)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors = 7)
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['pizza', 'pizza', 'pizza', 'pizza', 'pizza', 'pizza', 'pasta',
#        'pizza', 'pizza', 'pizza'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.4

# %%
# confusion_matrix(y_pred,y_test)
import matplotlib.pyplot as plt  
from sklearn.datasets import make_classification
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
x, y = make_classification(random_state=0)
x_train, x_test, y_train, y_test = train_test_split(
        x, y, random_state=0)
clf = SVC(random_state=0)
clf.fit(x_train, y_train)
SVC(random_state=0)
plot_confusion_matrix(clf, x_test, y_test)  
plt.show()

# %%
a=1
while a ==1:
  print("enter png or jpg pic link of pizza or pasta")
  path=input()
  img =imread(path)

  test_flat_data=[]
  imgs=[]
  img_resize = resize(img,(50,50,3))
  test_flat_data.append(img_resize.flatten())
  imgs.append(img_resize)

  output=model.predict(test_flat_data)
  print(output)
  print("try another pic press 1\n else enter 0")
  a=int(input())
# Out:
# enter png or jpg pic link of pizza or pasta
# https://images.unsplash.com/photo-1552539618-7eec9b4d1796?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxleHBsb3JlLWZlZWR8MjV8fHxlbnwwfHx8fA%3D%3D&w=1000&q=80
# ['pizza']
# try another pic press 1
#  else enter 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-b063fb7516ea> in <module>
#      14   print(output)
#      15   print("try another pic press 1\n else enter 0")
# ---> 16   a=int(input())
#
# c:\users\midhun\appdata\local\programs\python\python38\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# c:\users\midhun\appdata\local\programs\python\python38\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
